# %% [markdown]
# # Applied Data Science Capstone Project

# %% [markdown]
#  ### Either Toronto or New York City is the best city to open the new restaurant?

# %%
# A description of the problem and a discussion of the background.
# A description of the data and how it will be used to solve the problem.

# %% [markdown]
# ### Business Problem

# %% [markdown]
# The basic business problem of this assignment is how to identify the perfect spot for a new business , i.e. bar, coffee shop, restaurant. This project will be focused on the neighborhoods of Toronto and New York City. There are different categories of venues show in each neighborhood in each city. They will be classified by implementing classification method to see some some insights of each region.
#
# We are able to see precious information about the density of each type of business within the areas. It can be a preliminary analysis, saying that if there is no existence of certain types of business, it is more likely to tell that there is no demand of that particular service. On the other hand, it is also the new opportunity of the enterprise to enter the market. Please noted that this analysis is using only venues, without other socioeconomic/demographic information.

# %% [markdown]
# ### Data used

# %% [markdown]
# As mentioned earlier, the project will be concentrated on the city of Toronto and New York. Data for New York City will be taken fom the same resource of the previous assignments and data for Toronto will be scraped from Wikipedia (just like we did from last assignment).
#
# The Google Gecoder API will be used to extract geographical coordinates, then gererate map. The Foursquare API will also used for getting venues information of each neighborhood.
#
# The machine learning algorihm that might be presented is K-means clustering. It will be grouping the similar neighborhood together and some visualization will be provided as well.
